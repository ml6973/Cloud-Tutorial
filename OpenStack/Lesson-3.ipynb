# %% [markdown]
# <hr style="height:3px;border:none;color:#333;background-color:#333;" />
# <img style=" float:right; display:inline" src="http://opencloud.utsa.edu/wp-content/themes/utsa-oci/images/logo.png"/>
#
# ### **University of Texas at San Antonio**
# <br/>
# <br/>
# <span style="color:#000; font-family: 'Bebas Neue'; font-size: 2.5em;"> **Open Cloud Institute** </span>
#
# <hr style="height:3px;border:none;color:#333;background-color:#333;" />

# %% [markdown]
# ### OpenStack Cloud Networking
#
# <br/>
# <span style="color:#000; font-family: 'Bebas Neue'; font-size: 1.5em;"> **Paul Rad, Ph.D.** </span>
#
#
# <span style="color:#000; font-family: 'Bebas Neue'; font-size: 1.5em;"> **Gonzalo De La Torre, Ph.D. Student** </span>
#
# <span style="color:#000; font-family: 'Bebas Neue'; font-size: 1.4em;"> *Open Cloud Institute, University of Texas at San Antonio, San Antonio, Texas, USA* </span>
# <span style="color:#000; font-family: 'Bebas Neue'; font-size: 1.4em;"> {gonzalo.delatorreparra, paul.rad}@utsa.edu </span>
#
# <hr style="height:3px;border:none;color:#333;background-color:#333;" />

# %% [markdown]
# # Cloud Networking
# In today's data centers, networks are composed of more devices than ever before.
# Servers, switches, routers, storage systems, and security appliances now exist
# as virtual machines and virtual network appliances. These devices place a large
# strain on traditional network management systems, as they are unable to provide
# a scalable, automated approach to managing next-generation networks. Users now
# expect more control and flexibility of the infrastructure with quicker provisioning,
# all of which Cloud Networking promises to delive
# ## Functions Of Cloud Networking
# Cloud Networking includes many technologies one would find in a data center,
# including (**switching, routing, load balancing, firewalling, and virtual private networks**)aaS.
# These features can be configured to leverage open source or commercial software,
# and provide a cloud operator with all the tools necessary to build a functional and
# self-contained cloud.Cloud Networking also provides a framework for
# third-party vendors to build on and enhance the capabilities of the cloud
#
# ## Advantages of Software Defined Networks
# 1. **Cost Reduction,lowered capex**
# 2. **Overhead Reduction**
# 3. **Physical vs. Virtual Networking Management**
# 4. **Managing Virtual Packet Forwarding**
# 5. **Reduced Downtime**
# 6. **Isolation and Traffic Control**
# 7. **Extensibility**
# 8. **Central Networking Management Tool**
# 9. **Service provisioning speed and agility**
# 10. **Network flexibility and holistic management**
# 11. **Better granular security**
# 13. **Virtual network services **
#
#
#
# ## Neutron At A Glance
#
# * Give cloud tenants an API to build rich networking topologies, and configure advanced network policies in the cloud.
#  * Example: create multi-tier web application topology
# * Enable innovation plugins (open and closed source) that introduce advanced network capabilities
#  * Example: use L2-in-L3 tunneling to avoid VLAN limits, provide end-to-end QoS guarantees, use monitoring protocols like NetFlow.
# * Let anyone build advanced network services (open and closed source) that plug into Openstack tenant networks.
#  * Examples: LB-aaS, VPN-aaS, firewall-aaS, IDS-aaS (not implemented), data-center-interconnect-aaS.
# * Horizon GUI support for:
#  * Neutron L2 and L3 network and subnet creation/deletion
#  * Booting VMs on specific Neutron networks.
# * API Extensibility Framework, including extensions for:
#  * "provider network", which maps Neutron L2 networks to a specific VLAN in the physical data center
#
#
# ## Network Topologies Using Neutron
#  Network Topologies using Neutron is an architecture which describes the network  which includes the private and public networks hsving their interefaces which are connected each other with L3 and L2 devices.
#
# ![Image](https://github.com/cloudandbigdatalab/eLab-GUI-web-portal/blob/development/WebContent/resources/marketPlaceData/CloudNetworking/images/topology.png?raw=True)

# %% [markdown]
# ## Creating our 1st Complex Network Topology
# In our first complex topology we have one public network which is connected to the two router. Each routers are further connected to the two different private networks and two of them are connected to the instances.

# %% [markdown]
# ## Cleanig The Default Network Topology
# Chameleon Cloud provide user the by defalut public and private network which we can delete by following command and further we will create our own Environment.

# %%
ROUTER_ID=$(neutron router-list | grep router1 | grep -v '+' | grep -v 'external_gateway' | awk '{ print $2 }')
PRIVATE_SUBNET_ID=$(neutron subnet-list | grep '| private-subnet' | awk '{print $2}')
PUBLIC_SUBNET_ID=$(neutron subnet-list | grep '| public-subnet' | awk '{print $2}')
neutron router-gateway-clear $ROUTER_ID

for i in `neutron port-list | grep -v '+' | grep -v 'fixed_ips' | awk '{print $2}'`;
do
  neutron port-update --device-owner None $i;
  neutron port-delete $i;
done;

neutron router-delete router1
neutron net-delete public
neutron net-delete private

# %% [markdown]
# ## Creating The Topology Using Neutron CLI
# Neutron CLI enables the user to create, delete and modify the netowks which is composed of public/private network and L2 and L3 network components.

# %%
# %%bash
# . /home/stack/devstack/openrc admin admin
#
# neutron net-create --shared --provider:network_type flat --provider:physical_network flat --router:external my-public-network
#
# neutron subnet-create --name my-public-subnet-1 --gateway 10.10.10.1 --allocation-pool start=10.10.10.2,end=10.10.10.255 --dns-nameserver 8.8.8.8 my-public-network 10.10.0.0/16
# neutron subnet-create --name my-public-subnet-2 --gateway 10.20.10.1 --allocation-pool start=10.20.10.2,end=10.20.10.255 --dns-nameserver 8.8.8.8 my-public-network 10.20.0.0/16
#
# neutron net-create my-private-network-1
# neutron net-create my-private-network-2
# neutron net-create my-private-network-3
# neutron net-create my-private-network-4
#
# neutron subnet-create my-private-network-1 --name my-private-subnet-1 --gateway 192.168.0.1 192.168.0.0/24
# neutron subnet-create my-private-network-2 --name my-private-subnet-2 --gateway 192.169.0.1 192.169.0.0/24
# neutron subnet-create my-private-network-3 --name my-private-subnet-3 --gateway 192.170.0.1 192.170.0.0/24
# neutron subnet-create my-private-network-4 --name my-private-subnet-4 --gateway 192.171.0.1 192.171.0.0/24
#
# neutron router-create my-router-1
# neutron router-create my-router-2
#
# neutron router-interface-add my-router-1 my-public-subnet-1
# neutron router-interface-add my-router-2 my-public-subnet-2
#
# neutron router-interface-add my-router-1 my-private-subnet-1
# neutron router-interface-add my-router-1 my-private-subnet-2
# neutron router-interface-add my-router-2 my-private-subnet-3
# neutron router-interface-add my-router-2 my-private-subnet-4
#
# nova flavor-list
# glance image-list
#
# nova aggregate-create my-aggregate-0 compute-0
# nova aggregate-add-host my-aggregate-0 computenode0
#
# nova boot --flavor 1 --image cirros-0.3.4-x86_64-uec --security-groups default --availability-zone nova --nic net-name=my-private-network-1 my-instance-01
# nova boot --flavor 1 --image cirros-0.3.4-x86_64-uec --security-groups default --availability-zone compute-0 --nic net-name=my-private-network-4 my-instance-02
#
# nova list
# nova availability-zone-list
# Out:
# WARNING: setting legacy OS_TENANT_NAME to support cli tools.
# Created a new network:
# +---------------------------+--------------------------------------+
# | Field                     | Value                                |
# +---------------------------+--------------------------------------+
# | admin_state_up            | True                                 |
# | availability_zone_hints   |                                      |
# | availability_zones        |                                      |
# | created_at                | 2016-11-04T18:07:34                  |
# | description               |                                      |
# | id                        | 68bf58a2-0a91-4c2b-b712-4bfb26198aad |
# | ipv4_address_scope        |                                      |
# | ipv6_address_scope        |                                      |
# | is_default                | False                                |
# | mtu                       | 1500                                 |
# | name                      | my-public-network                    |
# | port_security_enabled     | True                                 |
# | provider:network_type     | flat                                 |
# | provider:physical_network | flat                                 |
# | provider:segmentation_id  |                                      |
# | router:external           | True                                 |
# | shared                    | True                                 |
# | status                    | ACTIVE                               |
# | subnets                   |                                      |
# | tags                      |                                      |
# | tenant_id                 | ec4b84f2bb2140dbb985c93badd2274c     |
# | updated_at                | 2016-11-04T18:07:34                  |
# +---------------------------+--------------------------------------+
# Created a new subnet:
# +-------------------+------------------------------------------------+
# | Field             | Value                                          |
# +-------------------+------------------------------------------------+
# | allocation_pools  | {"start": "10.10.10.2", "end": "10.10.10.255"} |
# | cidr              | 10.10.0.0/16                                   |
# | created_at        | 2016-11-04T18:07:35                            |
# | description       |                                                |
# | dns_nameservers   | 8.8.8.8                                        |
# | enable_dhcp       | True                                           |
# | gateway_ip        | 10.10.10.1                                     |
# | host_routes       |                                                |
# | id                | d62097d9-bf65-4d77-84fa-15d9ad2d9296           |
# | ip_version        | 4                                              |
# | ipv6_address_mode |                                                |
# | ipv6_ra_mode      |                                                |
# | name              | my-public-subnet-1                             |
# | network_id        | 68bf58a2-0a91-4c2b-b712-4bfb26198aad           |
# | subnetpool_id     |                                                |
# | tenant_id         | ec4b84f2bb2140dbb985c93badd2274c               |
# | updated_at        | 2016-11-04T18:07:35                            |
# +-------------------+------------------------------------------------+
# Created a new subnet:
# +-------------------+------------------------------------------------+
# | Field             | Value                                          |
# +-------------------+------------------------------------------------+
# | allocation_pools  | {"start": "10.20.10.2", "end": "10.20.10.255"} |
# | cidr              | 10.20.0.0/16                                   |
# | created_at        | 2016-11-04T18:07:36                            |
# | description       |                                                |
# | dns_nameservers   | 8.8.8.8                                        |
# | enable_dhcp       | True                                           |
# | gateway_ip        | 10.20.10.1                                     |
# | host_routes       |                                                |
# | id                | efb61133-c163-4447-aac3-f2d5fc233a7a           |
# | ip_version        | 4                                              |
# | ipv6_address_mode |                                                |
# | ipv6_ra_mode      |                                                |
# | name              | my-public-subnet-2                             |
# | network_id        | 68bf58a2-0a91-4c2b-b712-4bfb26198aad           |
# | subnetpool_id     |                                                |
# | tenant_id         | ec4b84f2bb2140dbb985c93badd2274c               |
# | updated_at        | 2016-11-04T18:07:36                            |
# +-------------------+------------------------------------------------+
# Created a new network:
# +---------------------------+--------------------------------------+
# | Field                     | Value                                |
# +---------------------------+--------------------------------------+
# | admin_state_up            | True                                 |
# | availability_zone_hints   |                                      |
# | availability_zones        |                                      |
# | created_at                | 2016-11-04T18:07:37                  |
# | description               |                                      |
# | id                        | 96b2617d-9370-4253-bbe4-6da33a9ddcb9 |
# | ipv4_address_scope        |                                      |
# | ipv6_address_scope        |                                      |
# | mtu                       | 1450                                 |
# | name                      | my-private-network-1                 |
# | port_security_enabled     | True                                 |
# | provider:network_type     | vxlan                                |
# | provider:physical_network |                                      |
# | provider:segmentation_id  | 1024                                 |
# | router:external           | False                                |
# | shared                    | False                                |
# | status                    | ACTIVE                               |
# | subnets                   |                                      |
# | tags                      |                                      |
# | tenant_id                 | ec4b84f2bb2140dbb985c93badd2274c     |
# | updated_at                | 2016-11-04T18:07:37                  |
# +---------------------------+--------------------------------------+
# Created a new network:
# +---------------------------+--------------------------------------+
# | Field                     | Value                                |
# +---------------------------+--------------------------------------+
# | admin_state_up            | True                                 |
# | availability_zone_hints   |                                      |
# | availability_zones        |                                      |
# | created_at                | 2016-11-04T18:07:38                  |
# | description               |                                      |
# | id                        | 9cd6112e-7673-4d78-b69b-41cc8a33b9cb |
# | ipv4_address_scope        |                                      |
# | ipv6_address_scope        |                                      |
# | mtu                       | 1450                                 |
# | name                      | my-private-network-2                 |
# | port_security_enabled     | True                                 |
# | provider:network_type     | vxlan                                |
# | provider:physical_network |                                      |
# | provider:segmentation_id  | 1009                                 |
# | router:external           | False                                |
# | shared                    | False                                |
# | status                    | ACTIVE                               |
# | subnets                   |                                      |
# | tags                      |                                      |
# | tenant_id                 | ec4b84f2bb2140dbb985c93badd2274c     |
# | updated_at                | 2016-11-04T18:07:38                  |
# +---------------------------+--------------------------------------+
# Created a new network:
# +---------------------------+--------------------------------------+
# | Field                     | Value                                |
# +---------------------------+--------------------------------------+
# | admin_state_up            | True                                 |
# | availability_zone_hints   |                                      |
# | availability_zones        |                                      |
# | created_at                | 2016-11-04T18:07:39                  |
# | description               |                                      |
# | id                        | fb58ce95-5211-4ca5-9205-a993aa13945c |
# | ipv4_address_scope        |                                      |
# | ipv6_address_scope        |                                      |
# | mtu                       | 1450                                 |
# | name                      | my-private-network-3                 |
# | port_security_enabled     | True                                 |
# | provider:network_type     | vxlan                                |
# | provider:physical_network |                                      |
# | provider:segmentation_id  | 1001                                 |
# | router:external           | False                                |
# | shared                    | False                                |
# | status                    | ACTIVE                               |
# | subnets                   |                                      |
# | tags                      |                                      |
# | tenant_id                 | ec4b84f2bb2140dbb985c93badd2274c     |
# | updated_at                | 2016-11-04T18:07:39                  |
# +---------------------------+--------------------------------------+
# Created a new network:
# +---------------------------+--------------------------------------+
# | Field                     | Value                                |
# +---------------------------+--------------------------------------+
# | admin_state_up            | True                                 |
# | availability_zone_hints   |                                      |
# | availability_zones        |                                      |
# | created_at                | 2016-11-04T18:07:40                  |
# | description               |                                      |
# | id                        | 916a9301-9d3b-40e6-b038-29d438c5bb88 |
# | ipv4_address_scope        |                                      |
# | ipv6_address_scope        |                                      |
# | mtu                       | 1450                                 |
# | name                      | my-private-network-4                 |
# | port_security_enabled     | True                                 |
# | provider:network_type     | vxlan                                |
# | provider:physical_network |                                      |
# | provider:segmentation_id  | 1068                                 |
# | router:external           | False                                |
# | shared                    | False                                |
# | status                    | ACTIVE                               |
# | subnets                   |                                      |
# | tags                      |                                      |
# | tenant_id                 | ec4b84f2bb2140dbb985c93badd2274c     |
# | updated_at                | 2016-11-04T18:07:40                  |
# +---------------------------+--------------------------------------+
# Created a new subnet:
# +-------------------+--------------------------------------------------+
# | Field             | Value                                            |
# +-------------------+--------------------------------------------------+
# | allocation_pools  | {"start": "192.168.0.2", "end": "192.168.0.254"} |
# | cidr              | 192.168.0.0/24                                   |
# | created_at        | 2016-11-04T18:07:41                              |
# | description       |                                                  |
# | dns_nameservers   |                                                  |
# | enable_dhcp       | True                                             |
# | gateway_ip        | 192.168.0.1                                      |
# | host_routes       |                                                  |
# | id                | 16c66724-9d00-4ee6-9ea6-08fc9133104b             |
# | ip_version        | 4                                                |
# | ipv6_address_mode |                                                  |
# | ipv6_ra_mode      |                                                  |
# | name              | my-private-subnet-1                              |
# | network_id        | 96b2617d-9370-4253-bbe4-6da33a9ddcb9             |
# | subnetpool_id     |                                                  |
# | tenant_id         | ec4b84f2bb2140dbb985c93badd2274c                 |
# | updated_at        | 2016-11-04T18:07:41                              |
# +-------------------+--------------------------------------------------+
# Created a new subnet:
# +-------------------+--------------------------------------------------+
# | Field             | Value                                            |
# +-------------------+--------------------------------------------------+
# | allocation_pools  | {"start": "192.169.0.2", "end": "192.169.0.254"} |
# | cidr              | 192.169.0.0/24                                   |
# | created_at        | 2016-11-04T18:07:42                              |
# | description       |                                                  |
# | dns_nameservers   |                                                  |
# | enable_dhcp       | True                                             |
# | gateway_ip        | 192.169.0.1                                      |
# | host_routes       |                                                  |
# | id                | ad24e9df-41d3-44ba-beae-afebd5ddd2a7             |
# | ip_version        | 4                                                |
# | ipv6_address_mode |                                                  |
# | ipv6_ra_mode      |                                                  |
# | name              | my-private-subnet-2                              |
# | network_id        | 9cd6112e-7673-4d78-b69b-41cc8a33b9cb             |
# | subnetpool_id     |                                                  |
# | tenant_id         | ec4b84f2bb2140dbb985c93badd2274c                 |
# | updated_at        | 2016-11-04T18:07:42                              |
# +-------------------+--------------------------------------------------+
# Created a new subnet:
# +-------------------+--------------------------------------------------+
# | Field             | Value                                            |
# +-------------------+--------------------------------------------------+
# | allocation_pools  | {"start": "192.170.0.2", "end": "192.170.0.254"} |
# | cidr              | 192.170.0.0/24                                   |
# | created_at        | 2016-11-04T18:07:43                              |
# | description       |                                                  |
# | dns_nameservers   |                                                  |
# | enable_dhcp       | True                                             |
# | gateway_ip        | 192.170.0.1                                      |
# | host_routes       |                                                  |
# | id                | 12fb250e-71fd-480e-9354-ae3374b897ff             |
# | ip_version        | 4                                                |
# | ipv6_address_mode |                                                  |
# | ipv6_ra_mode      |                                                  |
# | name              | my-private-subnet-3                              |
# | network_id        | fb58ce95-5211-4ca5-9205-a993aa13945c             |
# | subnetpool_id     |                                                  |
# | tenant_id         | ec4b84f2bb2140dbb985c93badd2274c                 |
# | updated_at        | 2016-11-04T18:07:43                              |
# +-------------------+--------------------------------------------------+
# Created a new subnet:
# +-------------------+--------------------------------------------------+
# | Field             | Value                                            |
# +-------------------+--------------------------------------------------+
# | allocation_pools  | {"start": "192.171.0.2", "end": "192.171.0.254"} |
# | cidr              | 192.171.0.0/24                                   |
# | created_at        | 2016-11-04T18:07:44                              |
# | description       |                                                  |
# | dns_nameservers   |                                                  |
# | enable_dhcp       | True                                             |
# | gateway_ip        | 192.171.0.1                                      |
# | host_routes       |                                                  |
# | id                | 3eb5d60c-8aad-459a-b4c0-7e59e2603efe             |
# | ip_version        | 4                                                |
# | ipv6_address_mode |                                                  |
# | ipv6_ra_mode      |                                                  |
# | name              | my-private-subnet-4                              |
# | network_id        | 916a9301-9d3b-40e6-b038-29d438c5bb88             |
# | subnetpool_id     |                                                  |
# | tenant_id         | ec4b84f2bb2140dbb985c93badd2274c                 |
# | updated_at        | 2016-11-04T18:07:44                              |
# +-------------------+--------------------------------------------------+
# Created a new router:
# +-------------------------+--------------------------------------+
# | Field                   | Value                                |
# +-------------------------+--------------------------------------+
# | admin_state_up          | True                                 |
# | availability_zone_hints |                                      |
# | availability_zones      |                                      |
# | description             |                                      |
# | distributed             | False                                |
# | external_gateway_info   |                                      |
# | ha                      | False                                |
# | id                      | cd67228a-551c-490c-a172-151bc07bfb3e |
# | name                    | my-router-1                          |
# | routes                  |                                      |
# | status                  | ACTIVE                               |
# | tenant_id               | ec4b84f2bb2140dbb985c93badd2274c     |
# +-------------------------+--------------------------------------+
# Created a new router:
# +-------------------------+--------------------------------------+
# | Field                   | Value                                |
# +-------------------------+--------------------------------------+
# | admin_state_up          | True                                 |
# | availability_zone_hints |                                      |
# | availability_zones      |                                      |
# | description             |                                      |
# | distributed             | False                                |
# | external_gateway_info   |                                      |
# | ha                      | False                                |
# | id                      | 4a147217-6667-4c21-8a5b-5f82089404dd |
# | name                    | my-router-2                          |
# | routes                  |                                      |
# | status                  | ACTIVE                               |
# | tenant_id               | ec4b84f2bb2140dbb985c93badd2274c     |
# +-------------------------+--------------------------------------+
# Added interface 4a77af75-21fd-4906-922e-efd898485804 to router my-router-1.
# Added interface e7dd4345-6857-40d3-8251-252003cf9e8b to router my-router-2.
# Added interface 24d61121-6546-4260-9724-9f29c2d3bd14 to router my-router-1.
# Added interface 5819a34e-1d7c-43db-ac71-c8678779e33d to router my-router-1.
# Added interface 32bbb2ec-88a3-43a6-9b07-5ef5332038f3 to router my-router-2.
# Added interface 1a017b01-5685-4a37-8528-c898e71d91bf to router my-router-2.
# +----+-----------+-----------+------+-----------+------+-------+-------------+-----------+
# | ID | Name      | Memory_MB | Disk | Ephemeral | Swap | VCPUs | RXTX_Factor | Is_Public |
# +----+-----------+-----------+------+-----------+------+-------+-------------+-----------+
# | 1  | m1.tiny   | 512       | 1    | 0         |      | 1     | 1.0         | True      |
# | 2  | m1.small  | 2048      | 20   | 0         |      | 1     | 1.0         | True      |
# | 3  | m1.medium | 4096      | 40   | 0         |      | 2     | 1.0         | True      |
# | 4  | m1.large  | 8192      | 80   | 0         |      | 4     | 1.0         | True      |
# | 42 | m1.nano   | 64        | 0    | 0         |      | 1     | 1.0         | True      |
# | 5  | m1.xlarge | 16384     | 160  | 0         |      | 8     | 1.0         | True      |
# | 84 | m1.micro  | 128       | 0    | 0         |      | 1     | 1.0         | True      |
# +----+-----------+-----------+------+-----------+------+-------+-------------+-----------+
# +--------------------------------------+---------------------------------+
# | ID                                   | Name                            |
# +--------------------------------------+---------------------------------+
# | fd23cd9f-1c72-4309-95b3-d969a4768333 | cirros-0.3.4-x86_64-uec         |
# | 01a518fe-1c9f-4dae-bd73-105a539e6626 | cirros-0.3.4-x86_64-uec-kernel  |
# | a3d68e9e-5336-468a-808e-aa411bffacb4 | cirros-0.3.4-x86_64-uec-ramdisk |
# +--------------------------------------+---------------------------------+
# +----+----------------+-------------------+-------+-------------------------------+
# | Id | Name           | Availability Zone | Hosts | Metadata                      |
# +----+----------------+-------------------+-------+-------------------------------+
# | 30 | my-aggregate-0 | compute-0         |       | 'availability_zone=compute-0' |
# +----+----------------+-------------------+-------+-------------------------------+
# Host computenode0 has been successfully added for aggregate 30
# +----+----------------+-------------------+----------------+-------------------------------+
# | Id | Name           | Availability Zone | Hosts          | Metadata                      |
# +----+----------------+-------------------+----------------+-------------------------------+
# | 30 | my-aggregate-0 | compute-0         | 'computenode0' | 'availability_zone=compute-0' |
# +----+----------------+-------------------+----------------+-------------------------------+
# +--------------------------------------+----------------------------------------------------------------+
# | Property                             | Value                                                          |
# +--------------------------------------+----------------------------------------------------------------+
# | OS-DCF:diskConfig                    | MANUAL                                                         |
# | OS-EXT-AZ:availability_zone          | nova                                                           |
# | OS-EXT-SRV-ATTR:host                 | -                                                              |
# | OS-EXT-SRV-ATTR:hostname             | my-instance-01                                                 |
# | OS-EXT-SRV-ATTR:hypervisor_hostname  | -                                                              |
# | OS-EXT-SRV-ATTR:instance_name        | instance-00000045                                              |
# | OS-EXT-SRV-ATTR:kernel_id            | 01a518fe-1c9f-4dae-bd73-105a539e6626                           |
# | OS-EXT-SRV-ATTR:launch_index         | 0                                                              |
# | OS-EXT-SRV-ATTR:ramdisk_id           | a3d68e9e-5336-468a-808e-aa411bffacb4                           |
# | OS-EXT-SRV-ATTR:reservation_id       | r-oarv3flf                                                     |
# | OS-EXT-SRV-ATTR:root_device_name     | -                                                              |
# | OS-EXT-SRV-ATTR:user_data            | -                                                              |
# | OS-EXT-STS:power_state               | 0                                                              |
# | OS-EXT-STS:task_state                | scheduling                                                     |
# | OS-EXT-STS:vm_state                  | building                                                       |
# | OS-SRV-USG:launched_at               | -                                                              |
# | OS-SRV-USG:terminated_at             | -                                                              |
# | accessIPv4                           |                                                                |
# | accessIPv6                           |                                                                |
# | adminPass                            | 8m8rHzbEXA8X                                                   |
# | config_drive                         |                                                                |
# | created                              | 2016-11-04T18:08:01Z                                           |
# | description                          | -                                                              |
# | flavor                               | m1.tiny (1)                                                    |
# | hostId                               |                                                                |
# | host_status                          |                                                                |
# | id                                   | 77606d42-c44f-48f5-8c70-d9b6880a4108                           |
# | image                                | cirros-0.3.4-x86_64-uec (fd23cd9f-1c72-4309-95b3-d969a4768333) |
# | key_name                             | -                                                              |
# | locked                               | False                                                          |
# | metadata                             | {}                                                             |
# | name                                 | my-instance-01                                                 |
# | os-extended-volumes:volumes_attached | []                                                             |
# | progress                             | 0                                                              |
# | security_groups                      | default                                                        |
# | status                               | BUILD                                                          |
# | tenant_id                            | ec4b84f2bb2140dbb985c93badd2274c                               |
# | updated                              | 2016-11-04T18:08:01Z                                           |
# | user_id                              | a75d117b19f147bbb893058f7f6ac369                               |
# +--------------------------------------+----------------------------------------------------------------+
# +--------------------------------------+----------------------------------------------------------------+
# | Property                             | Value                                                          |
# +--------------------------------------+----------------------------------------------------------------+
# | OS-DCF:diskConfig                    | MANUAL                                                         |
# | OS-EXT-AZ:availability_zone          | compute-0                                                      |
# | OS-EXT-SRV-ATTR:host                 | -                                                              |
# | OS-EXT-SRV-ATTR:hostname             | my-instance-02                                                 |
# | OS-EXT-SRV-ATTR:hypervisor_hostname  | -                                                              |
# | OS-EXT-SRV-ATTR:instance_name        | instance-00000046                                              |
# | OS-EXT-SRV-ATTR:kernel_id            | 01a518fe-1c9f-4dae-bd73-105a539e6626                           |
# | OS-EXT-SRV-ATTR:launch_index         | 0                                                              |
# | OS-EXT-SRV-ATTR:ramdisk_id           | a3d68e9e-5336-468a-808e-aa411bffacb4                           |
# | OS-EXT-SRV-ATTR:reservation_id       | r-9autha0v                                                     |
# | OS-EXT-SRV-ATTR:root_device_name     | -                                                              |
# | OS-EXT-SRV-ATTR:user_data            | -                                                              |
# | OS-EXT-STS:power_state               | 0                                                              |
# | OS-EXT-STS:task_state                | scheduling                                                     |
# | OS-EXT-STS:vm_state                  | building                                                       |
# | OS-SRV-USG:launched_at               | -                                                              |
# | OS-SRV-USG:terminated_at             | -                                                              |
# | accessIPv4                           |                                                                |
# | accessIPv6                           |                                                                |
# | adminPass                            | SgZzsSNW7wBg                                                   |
# | config_drive                         |                                                                |
# | created                              | 2016-11-04T18:08:03Z                                           |
# | description                          | -                                                              |
# | flavor                               | m1.tiny (1)                                                    |
# | hostId                               |                                                                |
# | host_status                          |                                                                |
# | id                                   | b518bb7d-2cff-47c1-a3e0-7faaa05962dc                           |
# | image                                | cirros-0.3.4-x86_64-uec (fd23cd9f-1c72-4309-95b3-d969a4768333) |
# | key_name                             | -                                                              |
# | locked                               | False                                                          |
# | metadata                             | {}                                                             |
# | name                                 | my-instance-02                                                 |
# | os-extended-volumes:volumes_attached | []                                                             |
# | progress                             | 0                                                              |
# | security_groups                      | default                                                        |
# | status                               | BUILD                                                          |
# | tenant_id                            | ec4b84f2bb2140dbb985c93badd2274c                               |
# | updated                              | 2016-11-04T18:08:03Z                                           |
# | user_id                              | a75d117b19f147bbb893058f7f6ac369                               |
# +--------------------------------------+----------------------------------------------------------------+
# +--------------------------------------+----------------+--------+------------+-------------+----------------------------------+
# | ID                                   | Name           | Status | Task State | Power State | Networks                         |
# +--------------------------------------+----------------+--------+------------+-------------+----------------------------------+
# | 77606d42-c44f-48f5-8c70-d9b6880a4108 | my-instance-01 | BUILD  | spawning   | NOSTATE     | my-private-network-1=192.168.0.3 |
# | b518bb7d-2cff-47c1-a3e0-7faaa05962dc | my-instance-02 | BUILD  | spawning   | NOSTATE     | my-private-network-4=192.171.0.3 |
# +--------------------------------------+----------------+--------+------------+-------------+----------------------------------+
# +-------------------------+----------------------------------------+
# | Name                    | Status                                 |
# +-------------------------+----------------------------------------+
# | internal                | available                              |
# | |- controlnode-instance |                                        |
# | | |- nova-conductor     | enabled :-) 2016-11-04T18:08:04.000000 |
# | | |- nova-scheduler     | enabled :-) 2016-11-04T18:08:00.000000 |
# | | |- nova-consoleauth   | enabled :-) 2016-11-04T18:08:00.000000 |
# | nova                    | available                              |
# | |- computenode1         |                                        |
# | | |- nova-compute       | enabled :-) 2016-11-04T18:08:04.000000 |
# | |- controlnode-instance |                                        |
# | | |- nova-compute       | enabled :-) 2016-11-04T18:07:56.000000 |
# | compute-0               | available                              |
# | |- computenode0         |                                        |
# | | |- nova-compute       | enabled :-) 2016-11-04T18:08:05.000000 |
# +-------------------------+----------------------------------------+

# %% [markdown]
# ## Output of The Code
# Using the above code user have created the network topology.

# %% [markdown]
# ## Cleaning-up Your Network Topology Using Neutron CLI
# As we used the Neutron CLI to create the Network toplogy, we can use it do delete the created topology with the help of commands.

# %%
# %%bash
# . /home/stack/devstack/openrc admin admin
#
# nova delete my-instance-01
# nova delete my-instance-02
#
# #Router 1, Public, Private 1,2
# ROUTER_ID=$(neutron router-list | grep my-router-1 | grep -v '+' | grep -v 'external_gateway' | awk '{ print $2 }')
# PRIVATE_SUBNET_ID=$(neutron subnet-list | grep '| my-private-subnet1' | awk '{print $2}')
# PUBLIC_SUBNET_ID=$(neutron subnet-list | grep '| my-public-subnet' | awk '{print $2}')
# neutron router-gateway-clear $ROUTER_ID
#
# for i in `neutron port-list | grep -v '+' | grep -v 'fixed_ips' | awk '{print $2}'`;
# do
#   if [ "$i" != "|" ]
#   then
#     neutron port-update --device-owner None $i;
#     neutron port-delete $i;
#   fi
# done;
#
# neutron router-delete my-router-1
# neutron net-delete my-public-network
# neutron net-delete my-private-network-1
# neutron net-delete my-private-network-2
#
# #Router 2, Private 3,4
# ROUTER_ID=$(neutron router-list | grep my-router-2 | grep -v '+' | grep -v 'external_gateway' | awk '{ print $2 }')
# PRIVATE_SUBNET_ID=$(neutron subnet-list | grep '| my-private-subnet3' | awk '{print $2}')
# neutron router-gateway-clear $ROUTER_ID
#
# for i in `neutron port-list | grep -v '+' | grep -v 'fixed_ips' | awk '{print $2}'`;
# do
#   neutron port-update --device-owner None $i;
#   neutron port-delete $i;
# done;
#
# neutron router-delete my-router-2
# neutron net-delete my-private-network-3
# neutron net-delete my-private-network-4
#
# nova aggregate-remove-host my-aggregate-0 computenode0
# nova aggregate-delete my-aggregate-0
# Out:
# WARNING: setting legacy OS_TENANT_NAME to support cli tools.
# Request to delete server my-instance-01 has been accepted.
# Request to delete server my-instance-02 has been accepted.
# Removed gateway from router cd67228a-551c-490c-a172-151bc07bfb3e
# Updated port: 04f5be29-399c-4efc-8e10-36f4b6187380
# Deleted port: 04f5be29-399c-4efc-8e10-36f4b6187380
# Updated port: 1a017b01-5685-4a37-8528-c898e71d91bf
# Deleted port: 1a017b01-5685-4a37-8528-c898e71d91bf
# Updated port: 20a1431c-2b24-485d-a723-2efa0e76c80a
# Deleted port: 20a1431c-2b24-485d-a723-2efa0e76c80a
# Updated port: 24d61121-6546-4260-9724-9f29c2d3bd14
# Deleted port: 24d61121-6546-4260-9724-9f29c2d3bd14
# Updated port: 2b79822c-d7a4-48ad-b9cd-2dc1adb73c87
# Deleted port: 2b79822c-d7a4-48ad-b9cd-2dc1adb73c87
# Updated port: 32bbb2ec-88a3-43a6-9b07-5ef5332038f3
# Deleted port: 32bbb2ec-88a3-43a6-9b07-5ef5332038f3
# Updated port: 4a77af75-21fd-4906-922e-efd898485804
# Deleted port: 4a77af75-21fd-4906-922e-efd898485804
# Updated port: 5819a34e-1d7c-43db-ac71-c8678779e33d
# Deleted port: 5819a34e-1d7c-43db-ac71-c8678779e33d
# Updated port: a6463fbd-70b8-48e6-9b82-9b05e7450b5f
# Deleted port: a6463fbd-70b8-48e6-9b82-9b05e7450b5f
# Updated port: e7dd4345-6857-40d3-8251-252003cf9e8b
# Deleted port: e7dd4345-6857-40d3-8251-252003cf9e8b
# Updated port: f4f202fc-f878-4573-9deb-8dc9e508ebcc
# Deleted port: f4f202fc-f878-4573-9deb-8dc9e508ebcc
# Deleted router: my-router-1
# Deleted network: my-public-network
# Deleted network: my-private-network-1
# Deleted network: my-private-network-2
# Removed gateway from router 4a147217-6667-4c21-8a5b-5f82089404dd
# Updated port: 07e56394-5193-4b4a-b82c-79bdbd748deb
# Deleted port: 07e56394-5193-4b4a-b82c-79bdbd748deb
# Updated port: b17a6a2e-666a-4791-a923-a9a9b39f1fc6
# Deleted port: b17a6a2e-666a-4791-a923-a9a9b39f1fc6
# Deleted router: my-router-2
# Deleted network: my-private-network-3
# Deleted network: my-private-network-4
# Host computenode0 has been successfully removed from aggregate 30
# +----+----------------+-------------------+-------+-------------------------------+
# | Id | Name           | Availability Zone | Hosts | Metadata                      |
# +----+----------------+-------------------+-------+-------------------------------+
# | 30 | my-aggregate-0 | compute-0         |       | 'availability_zone=compute-0' |
# +----+----------------+-------------------+-------+-------------------------------+
# Aggregate 30 has been successfully deleted.

# %% [markdown]
# ## Output
# Using the above code user have deleted the network topology.

# %% [markdown]
# ## Creating Our 1st NFV enabled Network Topology
# In this topology we have a a public network connected to the router, which is further connected to the our private network and nfv-test-network. There are two instances connected to the private network one of then is NFV enabled used to attack on the another instance.

# %%
# %%bash
# . /home/stack/devstack/openrc admin admin
#
# neutron net-create --shared --provider:network_type flat --provider:physical_network flat --router:external my-public-network
#
# neutron subnet-create --name my-public-subnet --gateway 10.40.10.1 --allocation-pool start=10.40.10.2,end=10.40.10.255 --dns-nameserver 8.8.8.8 my-public-network 10.40.0.0/16
#
# neutron net-create my-private-network
# neutron net-create my-nfv-test-network
#
# neutron subnet-create my-private-network --name my-private-subnet --gateway 192.173.0.1 192.173.0.0/24
# neutron subnet-create my-nfv-test-network --name my-nfv-test-subnet --gateway 192.174.0.1 192.174.0.0/24
#
# neutron router-create my-router
#
# neutron router-interface-add my-router my-public-subnet
# neutron router-interface-add my-router my-private-subnet
# neutron router-interface-add my-router my-nfv-test-subnet
#
# nova boot --flavor 1 --image cirros-0.3.4-x86_64-uec --security-groups default --availability-zone nova --nic net-name=my-private-network my-instance
# nova boot --flavor 1 --image cirros-0.3.4-x86_64-uec --security-groups default --availability-zone nova --nic net-name=my-private-network --nic net-name=my-nfv-test-network my-nfv-instance
# Out:
# WARNING: setting legacy OS_TENANT_NAME to support cli tools.
# Created a new network:
# +---------------------------+--------------------------------------+
# | Field                     | Value                                |
# +---------------------------+--------------------------------------+
# | admin_state_up            | True                                 |
# | availability_zone_hints   |                                      |
# | availability_zones        |                                      |
# | created_at                | 2016-11-04T18:15:28                  |
# | description               |                                      |
# | id                        | 3514fe5a-848f-4227-b281-8415e4aad6c6 |
# | ipv4_address_scope        |                                      |
# | ipv6_address_scope        |                                      |
# | is_default                | False                                |
# | mtu                       | 1500                                 |
# | name                      | my-public-network                    |
# | port_security_enabled     | True                                 |
# | provider:network_type     | flat                                 |
# | provider:physical_network | flat                                 |
# | provider:segmentation_id  |                                      |
# | router:external           | True                                 |
# | shared                    | True                                 |
# | status                    | ACTIVE                               |
# | subnets                   |                                      |
# | tags                      |                                      |
# | tenant_id                 | ec4b84f2bb2140dbb985c93badd2274c     |
# | updated_at                | 2016-11-04T18:15:28                  |
# +---------------------------+--------------------------------------+
# Created a new subnet:
# +-------------------+------------------------------------------------+
# | Field             | Value                                          |
# +-------------------+------------------------------------------------+
# | allocation_pools  | {"start": "10.40.10.2", "end": "10.40.10.255"} |
# | cidr              | 10.40.0.0/16                                   |
# | created_at        | 2016-11-04T18:15:29                            |
# | description       |                                                |
# | dns_nameservers   | 8.8.8.8                                        |
# | enable_dhcp       | True                                           |
# | gateway_ip        | 10.40.10.1                                     |
# | host_routes       |                                                |
# | id                | fa481a41-93f7-466e-8313-b3cc73c91daa           |
# | ip_version        | 4                                              |
# | ipv6_address_mode |                                                |
# | ipv6_ra_mode      |                                                |
# | name              | my-public-subnet                               |
# | network_id        | 3514fe5a-848f-4227-b281-8415e4aad6c6           |
# | subnetpool_id     |                                                |
# | tenant_id         | ec4b84f2bb2140dbb985c93badd2274c               |
# | updated_at        | 2016-11-04T18:15:29                            |
# +-------------------+------------------------------------------------+
# Created a new network:
# +---------------------------+--------------------------------------+
# | Field                     | Value                                |
# +---------------------------+--------------------------------------+
# | admin_state_up            | True                                 |
# | availability_zone_hints   |                                      |
# | availability_zones        |                                      |
# | created_at                | 2016-11-04T18:15:30                  |
# | description               |                                      |
# | id                        | 377025e6-87a1-4a17-bd09-4445ee0c0ef5 |
# | ipv4_address_scope        |                                      |
# | ipv6_address_scope        |                                      |
# | mtu                       | 1450                                 |
# | name                      | my-private-network                   |
# | port_security_enabled     | True                                 |
# | provider:network_type     | vxlan                                |
# | provider:physical_network |                                      |
# | provider:segmentation_id  | 1093                                 |
# | router:external           | False                                |
# | shared                    | False                                |
# | status                    | ACTIVE                               |
# | subnets                   |                                      |
# | tags                      |                                      |
# | tenant_id                 | ec4b84f2bb2140dbb985c93badd2274c     |
# | updated_at                | 2016-11-04T18:15:30                  |
# +---------------------------+--------------------------------------+
# Created a new network:
# +---------------------------+--------------------------------------+
# | Field                     | Value                                |
# +---------------------------+--------------------------------------+
# | admin_state_up            | True                                 |
# | availability_zone_hints   |                                      |
# | availability_zones        |                                      |
# | created_at                | 2016-11-04T18:15:31                  |
# | description               |                                      |
# | id                        | 5d3afc36-dc13-4708-898d-545efc7312e5 |
# | ipv4_address_scope        |                                      |
# | ipv6_address_scope        |                                      |
# | mtu                       | 1450                                 |
# | name                      | my-nfv-test-network                  |
# | port_security_enabled     | True                                 |
# | provider:network_type     | vxlan                                |
# | provider:physical_network |                                      |
# | provider:segmentation_id  | 1003                                 |
# | router:external           | False                                |
# | shared                    | False                                |
# | status                    | ACTIVE                               |
# | subnets                   |                                      |
# | tags                      |                                      |
# | tenant_id                 | ec4b84f2bb2140dbb985c93badd2274c     |
# | updated_at                | 2016-11-04T18:15:31                  |
# +---------------------------+--------------------------------------+
# Created a new subnet:
# +-------------------+--------------------------------------------------+
# | Field             | Value                                            |
# +-------------------+--------------------------------------------------+
# | allocation_pools  | {"start": "192.173.0.2", "end": "192.173.0.254"} |
# | cidr              | 192.173.0.0/24                                   |
# | created_at        | 2016-11-04T18:15:32                              |
# | description       |                                                  |
# | dns_nameservers   |                                                  |
# | enable_dhcp       | True                                             |
# | gateway_ip        | 192.173.0.1                                      |
# | host_routes       |                                                  |
# | id                | 43286db3-1c80-4dd1-8942-fe649f8c4429             |
# | ip_version        | 4                                                |
# | ipv6_address_mode |                                                  |
# | ipv6_ra_mode      |                                                  |
# | name              | my-private-subnet                                |
# | network_id        | 377025e6-87a1-4a17-bd09-4445ee0c0ef5             |
# | subnetpool_id     |                                                  |
# | tenant_id         | ec4b84f2bb2140dbb985c93badd2274c                 |
# | updated_at        | 2016-11-04T18:15:32                              |
# +-------------------+--------------------------------------------------+
# Created a new subnet:
# +-------------------+--------------------------------------------------+
# | Field             | Value                                            |
# +-------------------+--------------------------------------------------+
# | allocation_pools  | {"start": "192.174.0.2", "end": "192.174.0.254"} |
# | cidr              | 192.174.0.0/24                                   |
# | created_at        | 2016-11-04T18:15:33                              |
# | description       |                                                  |
# | dns_nameservers   |                                                  |
# | enable_dhcp       | True                                             |
# | gateway_ip        | 192.174.0.1                                      |
# | host_routes       |                                                  |
# | id                | 98f2d1ad-6bca-422d-9ea8-b459a93a2b76             |
# | ip_version        | 4                                                |
# | ipv6_address_mode |                                                  |
# | ipv6_ra_mode      |                                                  |
# | name              | my-nfv-test-subnet                               |
# | network_id        | 5d3afc36-dc13-4708-898d-545efc7312e5             |
# | subnetpool_id     |                                                  |
# | tenant_id         | ec4b84f2bb2140dbb985c93badd2274c                 |
# | updated_at        | 2016-11-04T18:15:33                              |
# +-------------------+--------------------------------------------------+
# Created a new router:
# +-------------------------+--------------------------------------+
# | Field                   | Value                                |
# +-------------------------+--------------------------------------+
# | admin_state_up          | True                                 |
# | availability_zone_hints |                                      |
# | availability_zones      |                                      |
# | description             |                                      |
# | distributed             | False                                |
# | external_gateway_info   |                                      |
# | ha                      | False                                |
# | id                      | 3fcd4717-a660-4661-90ce-46c1f9237815 |
# | name                    | my-router                            |
# | routes                  |                                      |
# | status                  | ACTIVE                               |
# | tenant_id               | ec4b84f2bb2140dbb985c93badd2274c     |
# +-------------------------+--------------------------------------+
# Added interface ea158760-fadc-42ba-8692-a1fa5e7d6112 to router my-router.
# Added interface fca074f2-f3bb-41e9-8743-57479cdd590e to router my-router.
# Added interface bbc6fcaf-3aa1-4caf-ae79-42bf24823bd3 to router my-router.
# +--------------------------------------+----------------------------------------------------------------+
# | Property                             | Value                                                          |
# +--------------------------------------+----------------------------------------------------------------+
# | OS-DCF:diskConfig                    | MANUAL                                                         |
# | OS-EXT-AZ:availability_zone          | nova                                                           |
# | OS-EXT-SRV-ATTR:host                 | -                                                              |
# | OS-EXT-SRV-ATTR:hostname             | my-instance                                                    |
# | OS-EXT-SRV-ATTR:hypervisor_hostname  | -                                                              |
# | OS-EXT-SRV-ATTR:instance_name        | instance-00000049                                              |
# | OS-EXT-SRV-ATTR:kernel_id            | 01a518fe-1c9f-4dae-bd73-105a539e6626                           |
# | OS-EXT-SRV-ATTR:launch_index         | 0                                                              |
# | OS-EXT-SRV-ATTR:ramdisk_id           | a3d68e9e-5336-468a-808e-aa411bffacb4                           |
# | OS-EXT-SRV-ATTR:reservation_id       | r-p0fht0q0                                                     |
# | OS-EXT-SRV-ATTR:root_device_name     | -                                                              |
# | OS-EXT-SRV-ATTR:user_data            | -                                                              |
# | OS-EXT-STS:power_state               | 0                                                              |
# | OS-EXT-STS:task_state                | scheduling                                                     |
# | OS-EXT-STS:vm_state                  | building                                                       |
# | OS-SRV-USG:launched_at               | -                                                              |
# | OS-SRV-USG:terminated_at             | -                                                              |
# | accessIPv4                           |                                                                |
# | accessIPv6                           |                                                                |
# | adminPass                            | MRZxWKBtQYn8                                                   |
# | config_drive                         |                                                                |
# | created                              | 2016-11-04T18:15:40Z                                           |
# | description                          | -                                                              |
# | flavor                               | m1.tiny (1)                                                    |
# | hostId                               |                                                                |
# | host_status                          |                                                                |
# | id                                   | 16f397fa-59db-4201-9669-ff5804a9c087                           |
# | image                                | cirros-0.3.4-x86_64-uec (fd23cd9f-1c72-4309-95b3-d969a4768333) |
# | key_name                             | -                                                              |
# | locked                               | False                                                          |
# | metadata                             | {}                                                             |
# | name                                 | my-instance                                                    |
# | os-extended-volumes:volumes_attached | []                                                             |
# | progress                             | 0                                                              |
# | security_groups                      | default                                                        |
# | status                               | BUILD                                                          |
# | tenant_id                            | ec4b84f2bb2140dbb985c93badd2274c                               |
# | updated                              | 2016-11-04T18:15:40Z                                           |
# | user_id                              | a75d117b19f147bbb893058f7f6ac369                               |
# +--------------------------------------+----------------------------------------------------------------+
# +--------------------------------------+----------------------------------------------------------------+
# | Property                             | Value                                                          |
# +--------------------------------------+----------------------------------------------------------------+
# | OS-DCF:diskConfig                    | MANUAL                                                         |
# | OS-EXT-AZ:availability_zone          | nova                                                           |
# | OS-EXT-SRV-ATTR:host                 | -                                                              |
# | OS-EXT-SRV-ATTR:hostname             | my-nfv-instance                                                |
# | OS-EXT-SRV-ATTR:hypervisor_hostname  | -                                                              |
# | OS-EXT-SRV-ATTR:instance_name        | instance-0000004a                                              |
# | OS-EXT-SRV-ATTR:kernel_id            | 01a518fe-1c9f-4dae-bd73-105a539e6626                           |
# | OS-EXT-SRV-ATTR:launch_index         | 0                                                              |
# | OS-EXT-SRV-ATTR:ramdisk_id           | a3d68e9e-5336-468a-808e-aa411bffacb4                           |
# | OS-EXT-SRV-ATTR:reservation_id       | r-oh4aty31                                                     |
# | OS-EXT-SRV-ATTR:root_device_name     | -                                                              |
# | OS-EXT-SRV-ATTR:user_data            | -                                                              |
# | OS-EXT-STS:power_state               | 0                                                              |
# | OS-EXT-STS:task_state                | scheduling                                                     |
# | OS-EXT-STS:vm_state                  | building                                                       |
# | OS-SRV-USG:launched_at               | -                                                              |
# | OS-SRV-USG:terminated_at             | -                                                              |
# | accessIPv4                           |                                                                |
# | accessIPv6                           |                                                                |
# | adminPass                            | 9ZFweVCDKEer                                                   |
# | config_drive                         |                                                                |
# | created                              | 2016-11-04T18:15:42Z                                           |
# | description                          | -                                                              |
# | flavor                               | m1.tiny (1)                                                    |
# | hostId                               |                                                                |
# | host_status                          |                                                                |
# | id                                   | 150a8d62-8340-497d-b820-352672f8d373                           |
# | image                                | cirros-0.3.4-x86_64-uec (fd23cd9f-1c72-4309-95b3-d969a4768333) |
# | key_name                             | -                                                              |
# | locked                               | False                                                          |
# | metadata                             | {}                                                             |
# | name                                 | my-nfv-instance                                                |
# | os-extended-volumes:volumes_attached | []                                                             |
# | progress                             | 0                                                              |
# | security_groups                      | default                                                        |
# | status                               | BUILD                                                          |
# | tenant_id                            | ec4b84f2bb2140dbb985c93badd2274c                               |
# | updated                              | 2016-11-04T18:15:42Z                                           |
# | user_id                              | a75d117b19f147bbb893058f7f6ac369                               |
# +--------------------------------------+----------------------------------------------------------------+

# %% [markdown]
# ## output
# Using the above code user have created  the NFV enabled network topology.

# %% [markdown]
# ## Cleaning-up Your NFV enabled Network Topology

# %%
# %%bash
# . /home/stack/devstack/openrc admin admin
#
# nova delete  my-instance
# nova delete  my-nfv-instance
#
#
# #Router 1, Public, Private 1,2
# ROUTER_ID=$(neutron router-list | grep my-nfv-router | grep -v '+' | grep -v 'external_gateway' | awk '{ print $2 }')
# PRIVATE_SUBNET_ID=$(neutron subnet-list | grep '| my-private-subnet' | awk '{print $2}')
# PRIVATE_SUBNET_ID=$(neutron subnet-list | grep '| my-nfv-test-subnet' | awk '{print $2}')
#
# PUBLIC_SUBNET_ID=$(neutron subnet-list | grep '| my-public-subnet' | awk '{print $2}')
# neutron router-gateway-clear $ROUTER_ID
#
# for i in `neutron port-list | grep -v '+' | grep -v 'fixed_ips' | awk '{print $2}'`;
# do
#   if [ "$i" != "|" ]
#   then
#     neutron port-update --device-owner None $i;
#     neutron port-delete $i;
#   fi
# done;
#
# neutron router-delete my-router
# neutron net-delete my-public-network
# neutron net-delete my-private-network
# neutron net-delete my-nfv-test-network
# Out:
# WARNING: setting legacy OS_TENANT_NAME to support cli tools.
# Request to delete server my-instance has been accepted.
# Request to delete server my-nfv-instance has been accepted.
# Updated port: 468f012b-03a1-4a80-8c05-6cb6baf09c23
# Deleted port: 468f012b-03a1-4a80-8c05-6cb6baf09c23
# Updated port: 6b59a1aa-3251-4814-833f-e543da5d9698
# Deleted port: 6b59a1aa-3251-4814-833f-e543da5d9698
# Updated port: bbc6fcaf-3aa1-4caf-ae79-42bf24823bd3
# Deleted port: bbc6fcaf-3aa1-4caf-ae79-42bf24823bd3
# Updated port: d86b9f14-298f-466e-a2ba-ef82a6790c62
# Deleted port: d86b9f14-298f-466e-a2ba-ef82a6790c62
# Updated port: ea158760-fadc-42ba-8692-a1fa5e7d6112
# Deleted port: ea158760-fadc-42ba-8692-a1fa5e7d6112
# Updated port: fca074f2-f3bb-41e9-8743-57479cdd590e
# Deleted port: fca074f2-f3bb-41e9-8743-57479cdd590e
# Deleted router: my-router
# Deleted network: my-public-network
# Deleted network: my-private-network
# Deleted network: my-nfv-test-network
# usage: neutron router-gateway-clear [-h] [--request-format {json}] ROUTER
# neutron router-gateway-clear: error: too few arguments
# Try 'neutron help router-gateway-clear' for more information.

# %% [markdown]
# ## output
# Using the above code user have deleted the NFV enabled network topology.
